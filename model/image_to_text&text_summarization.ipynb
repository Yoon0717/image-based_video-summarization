# %%
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done

# %%
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from transformers import AutoProcessor
from transformers import AutoModelForCausalLM
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

#processor = AutoProcessor.from_pretrained("microsoft/git-base")
#model = AutoModelForCausalLM.from_pretrained("microsoft/git-base")

model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/nlp_course/nlp-team_project/blip_base_freeze_finetuned_model.pth'))
# model.eval()
# Out:
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# <All keys matched successfully>

# %%
from datasets import load_dataset

dataset = load_dataset("imagefolder", data_dir= '/content/drive/MyDrive/Colab Notebooks/nlp_course/nlp-team_project/LAVA_S01_016_test', split="train")

dataset
# Out:
# Resolving data files:   0%|          | 0/332 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/332 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['image'],
#     num_rows: 332
# })

# %%
# load image
example = dataset[120]
print(example)
print()

image = example["image"]
print(image)
width, height = image.size
display(image.resize((int(0.3*width), int(0.3*height))))
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7AC44CA0ACE0>}
#
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7AC44CA0ACE0>
# <PIL.Image.Image image mode=RGB size=384x216>

# %%
import torch
from PIL import Image
import requests

# 모델을 올바른 장치로 이동
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
# Out:
# BlipForConditionalGeneration(
#   (vision_model): BlipVisionModel(
#     (embeddings): BlipVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (encoder): BlipEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x BlipEncoderLayer(
#           (self_attn): BlipAttention(
#             (dropout): Dropout(p=0.0, inplace=False)
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): BlipMLP(
#             (activation_fn): GELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (text_decoder): BlipTextLMHeadModel(
#     (bert): BlipTextModel(
#       (embeddings): BlipTextEmbeddings(
#         (word_embeddings): Embedding(30524, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (encoder): BlipTextEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BlipTextLayer(
#             (attention): BlipTextAttention(
#               (self): BlipTextSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): BlipTextSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (crossattention): BlipTextAttention(
#               (self): BlipTextSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): BlipTextSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BlipTextIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BlipTextOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (cls): BlipTextOnlyMLMHead(
#       (predictions): BlipTextLMPredictionHead(
#         (transform): BlipTextPredictionHeadTransform(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=768, out_features=30524, bias=True)
#       )
#     )
#   )
# )

# %%
all_captions = ""

for i in range(len(dataset)):

  image = dataset[i]["image"]
  # 입력 이미지
  inputs = processor(images=image, return_tensors="pt").to(device)
  pixel_values = inputs.pixel_values

  # 모델 실행
  generated_ids = model.generate(pixel_values=pixel_values, max_length=50)
  generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

  # 같은 문장은 1개만 허용
  if all_captions.count(generated_caption) < 2:
    all_captions += generated_caption + "\n"

print(all_captions)
# Out:
# red is standing with its mouth open, staring at the grown mushroom
# red is standing with its mouth open, staring at the spaghetti noodle
# red is standing with its mouth open, staring at the spaghetti noodle
# red is closing eyes with its mouth on the spaghetti noodle
# red is standing with its mouth open, tracing onto the spaghetti noodle
# the spaghetti noodle is moving and red is surprised
# the spaghetti noodle is moving and red is surprised
# the spaghetti noodle is moving and red is jumping to noodle
# red bites into the moving spaghetti noodle
# red bites into the moving spaghetti noodle
# yellow is eating a spaghetti noodle, and red, who is biting into the noodle, is being pulled toward yellow
# yellow is eating a spaghetti noodle, and red, who is biting into the noodle, is being pulled toward yellow
# red pulls the spaghetti noodle that yellow is biting it to free him
# red pulled the spaghetti noodles and yellow panicked
# red pulled the spaghetti noodles and yellow panicked
# someone pulled the spaghetti noodles and yellow panicked
# someone pulled the spaghetti noodles and yellow panicked
# yellow pulls on the spaghetti noodles as hard as he can to avoid being dragged away
# yellow pulls on the spaghetti noodles as hard as he can to avoid being dragged away
# red and yellow bite and kiss one spaghetti noodle
# red and yellow bite and kiss one spaghetti noodle
# red and yellow bite and kiss one spaghetti noodle and yellow likes it.
# red and yellow bite and kiss one spaghetti noodle and yellow likes it.
# red jumps up and down in surprise and yellow smiles.
# red jumps up and down in surprise and yellow smiles.
# yellow bites down on something and looks away
# yellow bites down on something and looks away
# yellow feels paradise
# yellow feels paradise
# red rolls into spaghetti noodles
# red rolls into spaghetti noodles
# red is collapsed with spaghetti noodles on top of his body
# red is collapsed with spaghetti noodles on top of his body
# red is lying on the ground with spaghetti noodles on top of his body and yellow is approaching him
# red is lying on the ground with spaghetti noodles on top of his body and yellow is approaching him
# red is lying on the ground with spaghetti noodles on top of his body and yellow is staring at him with his mouth open
# red is lying on the ground with spaghetti noodles on top of his body and yellow is staring at him with his mouth open
# red is lying on the ground with spaghetti noodles on top of his body and yellow is trying to eat them with his tongue out
# red is lying on the ground with spaghetti noodles on top of his body and yellow is trying to eat them with his tongue out
# red stands with a spaghetti noodle on top of his body and pokes yellow, and yellow gets scared
# red stands with a spaghetti noodle on top of his body and pokes yellow, and yellow gets scared
# red stands with a spaghetti noodle on top of his body and sticks his tongue out while looking at the noodle. yellow sticks his tongue out and looks at it
# red stands with spaghetti noodles on top of his body and sticks his tongue out while looking at the noodles, yellow sticks his tongue out and looks at
# red stands with spaghetti noodles on top of his body and sticks his tongue out while looking at the noodles, yellow sticks his tongue out and looks at
# red stands with a spaghetti noodle on top of his body and sticks his tongue out while looking at the noodle. yellow sticks his tongue out and looks at it
# red stands with spaghetti noodles on top of his body and looks at the noodles and smiles yellow sticks his tongue out and looks at them
# red sticks his tongue out while looking down at the spaghetti noodles on his body, yellow sticks his tongue out and looks up
# red sticks his tongue out while looking down at the spaghetti noodles on his body, yellow sticks his tongue out and looks up
# red looks down at the spaghetti noodles on top of his body and tries to eat them, yellow sticks out his tongue and looks up
# red looks down at the spaghetti noodles on top of his body and tries to eat them, yellow sticks out his tongue and looks up
# red is holding the spaghetti noodles on top of his body and looking down at them, yellow is eating them to free him
# red shakes himself to get the spaghetti noodles off his body, yellow looks on wistfully
# red shakes himself to get the spaghetti noodles off his body, yellow looks on wistfully
# red is holding his spaghetti noodles in front of him, and yellow is looking at him with his mouth open
# red is holding his spaghetti noodles in front of him, and yellow is looking at him curiously
# red is lying on the ground with spaghetti noodles on top of his body and yellow is looking at him with his mouth open
# red is lying down to get the spaghetti noodles away from his body, yellow is sticking out his tongue
# red lies down to get the spaghetti noodles away from his body, and yellow sticks his tongue out to eat them
# red lies down to get the spaghetti noodles off his body, and yellow sticks his tongue out to eat them
# red wakes up with spaghetti noodles and yellow panics
# red wakes up with spaghetti noodles and yellow panics
# red is standing with spaghetti noodles stuck to him and yellow is panicking
# red is standing with spaghetti noodles stuck to him, and yellow is looking at them.
# red is standing with spaghetti noodles on top of his body and yellow is panicking
# red is standing with spaghetti noodles stuck to him and yellow is panicking
# red jumps up with spaghetti noodles stuck to him, and yellow looks on wistfully
# red looks surprised to see a spaghetti noodle stuck to him, and yellow is stuffing it into his mouth
# red looks surprised to see a spaghetti noodle stuck to him, and yellow is stuffing it into his mouth
# red is holding the spaghetti noodles on top of his body and looking at them with yellow on his body, while yellow is eating them
# yellow is eating the spaghetti noodles on top of red, and red leans back to prevent her from eating them
# yellow is eating the spaghetti noodles on top of red, and red leans back to prevent her from eating them
# red takes a bite out of his spaghetti noodle, and yellow looks on in amazement
# yellow looks up in surprise
# yellow looks up in surprise
# red is lying with spaghetti noodles wrapped around his body
# red is lying with spaghetti noodles wrapped around his body
# red is lying down with spaghetti noodles wrapped around his body, and yellow is approaching
# red is lying down with spaghetti noodles wrapped around his body, and yellow is approaching
# red is lying down with spaghetti noodles wrapped around his body, and yellow is eating them to free him
# red is lying down with spaghetti noodles wrapped around his body, and yellow is eating them to free him
# red bounces and yellow releases the spaghetti noodles and eats them all
# red is down and yellow is happy
# red is down and yellow is happy
# red pokes at yellow, and yellow looks satisfied
# red pokes at yellow, and yellow looks satisfied
# spaghetti noodles come down from above, yellow and red both look at them with eager eyes
# spaghetti noodles come down from above, yellow and red both look at them with eager eyes
# spaghetti noodles come down from above, yellow sticks her tongue out to eat them, red sees this and gets upset
# spaghetti noodles come down from above, red and yellow bite and kiss each other
# spaghetti noodles come down from above, yellow swallows his saliva and looks at them, red sees this and gets upset
# yellow is hanging on to a spaghetti noodle from above, with red candles in the air
# spaghetti noodles come down from above, yellow hanging on to them with his mouth, while red is hanging on to his body
# yellow is hanging on to a spaghetti noodle from above with his mouth, while red is falling from above
# yellow is hanging on to a spaghetti noodle from above with his mouth, while red is hanging on to the noodle from above
# a spaghetti noodle hanging from the top with yellow holding it in his mouth and red standing over yellow
# a spaghetti noodle hanging from the top with yellow holding it in his mouth and red standing over yellow
# yellow is hanging on to the spaghetti noodle from above with his mouth, while red is jumping to yellow
# the spaghetti noodle from the top is hanging on to the spaghetti noodle from the top, with yellow in his mouth and red's mouth hanging on the noodle
# a spaghetti noodle hanging down from the top with yellow holding it in his mouth and red standing over yellow
# red and yellow are gone
# a spaghetti noodle hanging down from the top with yellow holding it in his mouth and red standing over yellow
# red is jumping to the side of the spaghetti noodle, and yellow is falling down
# yellow is floating in the sky with a noodle in his mouth, and red is floating on top of him
# yellow is floating in the sky with a noodle in his mouth, and red is floating on top of him
# yellow is holding the noodle in his mouth, and red is falling at full speed
# red and yellow are wrapped in spaghetti noodles and holding each other
# red and yellow are wrapped in spaghetti noodles and holding each other
# red and yellow are not close to each other
# red and yellow are jumping to the side of the spaghetti noodles
# red and yellow are jumping to the side of the spaghetti noodles
# red and yellow are lying next to their respective spaghetti noodles
# red and yellow are lying next to their respective spaghetti noodles
# red is lying next to the spaghetti noodles and yellow is happy to see them
# red is lying next to the spaghetti noodles and yellow is happy to see them
# yellow is eating spaghetti noodles and red is lying down and looking at them curiously
# yellow is eating spaghetti noodles and red is lying down and looking at them curiously
# red and yellow have one spaghetti noodle in their mouths and both look at the sky in confusion
# red jumps to eat the spaghetti noodles, and yellow, who is eating the spaghetti noodles, panics
# red and yellow have one spaghetti noodle in their mouths together
# red and yellow have one spaghetti noodle in their mouths together
# yellow has a spaghetti noodle in his mouth and is very flustered
# yellow has a spaghetti noodle in his mouth and is very flustered
# yellow has a spaghetti noodle in his mouth and is looking up, very puzzled
# red has a spaghetti noodle in his mouth and is looking up, very puzzled
# red has a spaghetti noodle in his mouth and is looking up, very puzzled
# spaghetti noodles dangling through a gap in the ceiling
# spaghetti noodles dangling through a gap in the ceiling
# red and yellow have one spaghetti noodle in their mouths and both look at the sky in confusion
# red and yellow drop the spaghetti noodles out of their mouths and look at the sky and freak out
# red and yellow drop the spaghetti noodles out of their mouths and look at the sky and freak out
# red and yellow drop the spaghetti noodles from their mouths and look up at the sky, freaking out. the ceiling falls with the spaghetti noodles hanging from the gap
# red and yellow drop the spaghetti noodles from their mouths and look up at the sky, freaking out. the ceiling falls with the spaghetti noodles hanging from the gap
# a ceiling with spaghetti noodles falling through a gap
# a ceiling with spaghetti noodles falling through a gap
# red and yellow are lying on the sewer lid
# red and yellow are lying on the sewer lid
# red and yellow are lying on a sewer lid, red is throwing up, and yellow is freaking out
# red and yellow are lying on a sewer lid, red is throwing up, and yellow is freaking out
# red and yellow are lying on a sewer lid, red is throwing up, and yellow is eating spaghetti noodles
# red and yellow are lying on a sewer lid, red is throwing up, and yellow is eating spaghetti noodles
# red and yellow are lying on a sewer lid, with red throwing up and yellow looking satisfied
# red and yellow are lying on a sewer lid, with red throwing up and yellow looking satisfied

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def split_string_in_thirds(s):
    third_length = len(s) // 3
    first_third = s[:third_length]
    second_third = s[third_length:2*third_length]
    third_third = s[2*third_length:]

    return first_third, second_third, third_third


first_third, second_third, third_third = split_string_in_thirds(all_captions)


sum1 = summarizer(first_third, max_length=200, min_length=30, do_sample=False)[0]['summary_text']
sum2 = summarizer(second_third, max_length=200, min_length=30, do_sample=False)[0]['summary_text']
sum3 = summarizer(third_third, max_length=200, min_length=30, do_sample=False)[0]['summary_text']

sum = summarizer(sum1+sum2+sum3, max_length=100, min_length=30, do_sample=False)
print(sum[0]['summary_text'])
# Out:
# The story is about a boy and a girl playing with spaghetti noodles. The boy tries to get the spaghetti noodles off his body and eats them. The girl eats the noodles on top of red.
